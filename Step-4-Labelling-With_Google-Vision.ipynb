# %%
from google.cloud import vision
# Out:
# Collecting google-cloud-vision
#   Downloading google_cloud_vision-3.7.2-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting gensim
#   Downloading gensim-4.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.18.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-cloud-vision) (2.26.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-cloud-vision) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-cloud-vision) (4.23.4)
# Requirement already satisfied: numpy>=1.18.5 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.28.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.60.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio_status-1.62.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.9)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision)
#   Downloading grpcio-1.62.2-cp310-cp310-macosx_12_0_universal2.whl.metadata (4.0 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arham/anaconda3/envs/DataScience/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2024.2.2)
# Downloading google_cloud_vision-3.7.2-py2.py3-none-any.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.6/459.6 kB 6.1 MB/s eta 0:00:00a 0:00:01
# Downloading gensim-4.3.2-cp310-cp310-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 7.4 MB/s eta 0:00:00:00:0100:01
# Downloading grpcio_status-1.62.2-py3-none-any.whl (14 kB)
# Downloading grpcio-1.62.2-cp310-cp310-macosx_12_0_universal2.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 10.5 MB/s eta 0:00:0000:010:01
# Installing collected packages: grpcio, grpcio-status, gensim, google-cloud-vision
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.60.0
#     Uninstalling grpcio-1.60.0:
#       Successfully uninstalled grpcio-1.60.0
# Successfully installed gensim-4.3.2 google-cloud-vision-3.7.2 grpcio-1.62.2 grpcio-status-1.62.2

# %%
import pandas as pd
df_final = pd.read_csv('shortlisted_influencers.csv')
df_final.head()
# Out:
#         author_name                                            post_id  \
# 0  kayaancontractor  kayaancontractor_100226_2868439159916464863_205_2
# 1    masoomminawala  masoomminawala_1355818_3045266610416022503_836...
# 2    masoomminawala  masoomminawala_1355818_3033605769618108996_147...
# 3      shwetarohira  shwetarohira_533824_3025671556883784297_27471_111
# 4       taramilktea  taramilktea_1371196_2995209944266875308_15974_...
#
#                         image_ID  comments_count  likes_count  \
# 0  2022-06-25_13-43-36_UTC_1.jpg               2          205
# 1  2023-02-24_13-08-10_UTC_1.jpg             881        83647
# 2  2023-02-08_11-00-10_UTC_1.jpg              87        14762
# 3    2023-01-28_12-16-18_UTC.jpg             111        27471
# 4  2022-12-17_11-34-31_UTC_1.jpg            2089        15974
#
#                                              caption       date  year  month  \
# 0  “Got your nose!”🫶🏻 #caturday \n.\n#saturday #l...  2022-06-2  2022      6
# 1                                                🦁\n  2023-02-2  2023      2
# 2  Colour I have been loving lately: 🤍🕊️\n\nTop: ...  2023-02-0  2023      2
# 3                       Feeling like a 🦩💕\n.\n.\n.\n  2023-01-2  2023      1
# 4  Underneath the tree … the ultimate gifts, @dio...  2022-12-1  2022     12
#
#    day          category
# 0    2  Core Influencers
# 1    2  Core Influencers
# 2    0  Core Influencers
# 3    2  Core Influencers
# 4    1  Core Influencers

# %%
from google.cloud import vision

def detect_labels(image_path):
    client = vision.ImageAnnotatorClient()

    with open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.label_detection(image=image)
    labels = response.label_annotations

    labels_all = ""

    
    for label in labels:
        # print(label.description)
        labels_all += label.description + ","

    return labels_all
    
# # Specify the path to your local image
# image_path = 'Data/aashnashroff_969148_3000403601659402518_25980_65/2022-12-24_15-33-23_UTC_1.jpg'

# # Call the label detection function

# print(detect_labels(image_path))
# Out:
# Sky,Cloud,Leg,Flash photography,Happy,Travel,Thigh,Waist,Leisure,Fun,

# %% [markdown]
# Security locking the code cell below to avoid accidental execution

# %%
# # Add a new column 'labels' to the DataFrame
# label_list = []
# for i in range(len(df_final)):
#     image_path = "Data/" + df_final['post_id'].iloc[i] + "/" + df_final['image_ID'].iloc[i]
#     labels = detect_labels(image_path)
#     label_list.append(labels)
#     if i % 30 == 0:
#         print(i)

# df_final['labels'] = label_list
# df_final

# #save csv
# df_final.to_csv('Shortlisted_Influencer_Posts_With_Labels.csv', index=False)
# Out:
# 0
# 30
# 60
# 90
# 120
# 150
# 180
# 210
# 240

# %%
df_final
# Out:
#            author_name                                            post_id  \
# 0     kayaancontractor  kayaancontractor_100226_2868439159916464863_205_2
# 1       masoomminawala  masoomminawala_1355818_3045266610416022503_836...
# 2       masoomminawala  masoomminawala_1355818_3033605769618108996_147...
# 3         shwetarohira  shwetarohira_533824_3025671556883784297_27471_111
# 4          taramilktea  taramilktea_1371196_2995209944266875308_15974_...
# ..                 ...                                                ...
# 265     masoomminawala  masoomminawala_1355818_3067704706607931376_139...
# 266        diipakhosla   diipakhosla_1908495_3053929039879187516_10953_66
# 267  yasminkarachiwala  yasminkarachiwala_1062568_2727848691991862333_...
# 268   kayaancontractor  kayaancontractor_100226_3018217689202415643_65...
# 269  yasminkarachiwala  yasminkarachiwala_1062568_2813329952305644743_...
#
#                           image_ID  comments_count  likes_count  \
# 0    2022-06-25_13-43-36_UTC_1.jpg               2          205
# 1    2023-02-24_13-08-10_UTC_1.jpg             881        83647
# 2    2023-02-08_11-00-10_UTC_1.jpg              87        14762
# 3      2023-01-28_12-16-18_UTC.jpg             111        27471
# 4    2022-12-17_11-34-31_UTC_1.jpg            2089        15974
# ..                             ...             ...          ...
# 265  2023-03-27_12-08-40_UTC_1.jpg              49        13982
# 266  2023-03-08_11-58-52_UTC_1.jpg              66        10953
# 267  2021-12-13_14-15-26_UTC_1.jpg              89         7799
# 268  2023-01-18_05-26-48_UTC_1.jpg              25          652
# 269  2022-04-10_12-51-26_UTC_1.jpg             116         3897
#
#                                                caption       date  year  \
# 0    “Got your nose!”🫶🏻 #caturday \n.\n#saturday #l...  2022-06-2  2022
# 1                                                  🦁\n  2023-02-2  2023
# 2    Colour I have been loving lately: 🤍🕊️\n\nTop: ...  2023-02-0  2023
# 3                         Feeling like a 🦩💕\n.\n.\n.\n  2023-01-2  2023
# 4    Underneath the tree … the ultimate gifts, @dio...  2022-12-1  2022
# ..                                                 ...        ...   ...
# 265  PSA: Keep that glass of water close, but a wat...  2023-03-2  2023
# 266  Happy International Women’s Day to all you FOR...  2023-03-0  2023
# 267  Haldi Ceremony is a fun filled riot!! \nAs you...  2021-12-1  2021
# 268  Under the Gliricidia Bloom🌸 \n.\nPhotography: ...  2023-01-1  2023
# 269  Make it simple, but significant💥\n\nMakeup- @m...  2022-04-1  2022
#
#      month  day          category  \
# 0        6    2  Core Influencers
# 1        2    2  Core Influencers
# 2        2    0  Core Influencers
# 3        1    2  Core Influencers
# 4       12    1  Core Influencers
# ..     ...  ...               ...
# 265      3    2  Core Influencers
# 266      3    0  Core Influencers
# 267     12    1  Core Influencers
# 268      1    1  Core Influencers
# 269      4    1  Core Influencers
#
#                                                 labels
# 0    Nose,Glasses,Skin,Lip,Vision care,Eyebrow,Mout...
# 1    Face,Fur clothing,Textile,Gesture,Happy,Flash ...
# 2    Neck,Sleeve,Waist,Collar,Blazer,Curtain,Formal...
# 3    Clothing,Footwear,Arm,Shoulder,Dress,Human bod...
# 4    Christmas tree,Plant,Property,Christmas orname...
# ..                                                 ...
# 265  Shoulder,Comfort,Textile,Sleeve,Couch,Flooring...
# 266  Sky,Smile,Cloud,Shorts,Plant,Tree,Happy,People...
# 267  Shoulder,Vision care,Neck,Purple,Sleeve,Eyewea...
# 268  Hair,Sky,People in nature,Plant,Waist,Flash ph...
# 269  Lip,Outerwear,Shoulder,Neck,Sleeve,Collar,Wais...
#
# [270 rows x 12 columns]
