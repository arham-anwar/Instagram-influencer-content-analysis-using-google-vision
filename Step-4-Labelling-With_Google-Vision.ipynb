# %%
from google.cloud import vision

# %%
import pandas as pd
df_final = pd.read_csv('shortlisted_influencers.csv')

# filter to authors in Core_Influencers = ['sahilkhan', 'taramilktea', 'masoomminawala','diipakhosla','aashnashroff', 'yasminkarachiwala', 'shwetarohira', 'houseofmisu', 'akanksharedhu', 'kayaancontractor']
df_final = df_final[df_final['author_name'].isin(['sahilkhan', 'taramilktea', 'masoomminawala','diipakhosla','aashnashroff', 'yasminkarachiwala', 'shwetarohira', 'houseofmisu', 'akanksharedhu', 'kayaancontractor'])]

df_final.head()
# Out:
#                                              post_id  \
# 0  kayaancontractor_100226_2868439159916464863_205_2
# 1  kayaancontractor_100226_2868439159916464863_205_2
# 2  kayaancontractor_100226_2868439159916464863_205_2
# 3  masoomminawala_1355818_3045266610416022503_836...
# 4  masoomminawala_1355818_3045266610416022503_836...
#
#                         image_ID  comments_count  likes_count  followers  \
# 0  2022-06-25_13-43-36_UTC_1.jpg               2          205          0
# 1  2022-06-25_13-43-36_UTC_2.jpg               2          205          0
# 2  2022-06-25_13-43-36_UTC_3.jpg               2          205          0
# 3  2023-02-24_13-08-10_UTC_1.jpg             881        83647          0
# 4  2023-02-24_13-08-10_UTC_2.jpg             881        83647          0
#
#         author_name                                            caption  \
# 0  kayaancontractor  “Got your nose!”🫶🏻 #caturday \n.\n#saturday #l...
# ...

# %% [markdown]
# Security locking the code cell below to avoid accidental execution

# %%
# # Add a new column 'labels' to the DataFrame
# label_list = []
# for i in range(len(df_final)):
#     image_path = "Data/" + df_final['post_id'].iloc[i] + "/" + df_final['image_ID'].iloc[i]
#     labels = detect_labels(image_path)
#     label_list.append(labels)
#     if i % 100 == 0:
#         print(i)

# df_final['labels'] = label_list
# df_final

# #save csv
# df_final.to_csv('Shortlisted_Influencer_Posts_With_Labels.csv', index=False)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
df_final
# Out:
#                                                 post_id  \
# 0     kayaancontractor_100226_2868439159916464863_205_2
# 1     kayaancontractor_100226_2868439159916464863_205_2
# 2     kayaancontractor_100226_2868439159916464863_205_2
# 3     masoomminawala_1355818_3045266610416022503_836...
# 4     masoomminawala_1355818_3045266610416022503_836...
# ...                                                 ...
# 1140  kayaancontractor_100226_3018217689202415643_65...
# 1141  kayaancontractor_100226_3018217689202415643_65...
# 1142  kayaancontractor_100226_3018217689202415643_65...
# 1143  yasminkarachiwala_1062568_2813329952305644743_...
# 1144  yasminkarachiwala_1062568_2813329952305644743_...
#
#                            image_ID  comments_count  likes_count  followers  \
# 0     2022-06-25_13-43-36_UTC_1.jpg               2          205          0
# 1     2022-06-25_13-43-36_UTC_2.jpg               2          205          0
# ...
